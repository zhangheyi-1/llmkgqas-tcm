# %%
import pickle

# %%
with open('new_train.pk','rb') as f:
    data = pickle.load(f)

# %%
print(type(data), len(data))
# Out:
# <class 'list'> 14864

# %%
data[0]
# Out:
# [{'id': 'Patients',
#   'Sentence': '你好，肚脐周围隐隐作痛，不知道怎么回事（女，29岁）',
#   'Symptom': ['腹痛'],
#   'Medicine': [],
#   'Test': [],
#   'Attribute': [],
#   'Disease': []},
#  {'id': 'Doctor',
#   'Sentence': '你好，这种情况多长时间了？',
#   'Symptom': [],
#   'Medicine': [],
#   'Test': [],
#   'Attribute': ['时长'],
#   'Disease': []},
#  {'id': 'Patients',
#   'Sentence': '两三天了。',
#   'Symptom': [],
#   'Medicine': [],
#   'Test': [],
#   'Attribute': [],
#   'Disease': []},
#  {'id': 'Patients',
#   'Sentence': '隐隐作痛，疼一会就不疼了。',
#   'Symptom': [],
#   'Medicine': [],
#   'Test': [],
#   'Attribute': [],
#   'Disease': []},
#  {'id': 'Doctor',
#   'Sentence': '有没有用过什么药？做过什么检查吗。',
#   'Symptom': [],
#   'Medicine': [],
#   'Test': [],
#   'Attribute': [],
#   'Disease': []},
#  {'id': 'Patients',
#   'Sentence': '没有用药，也没有检查。',
#   'Symptom': [],
#   'Medicine': [],
#   'Test': [],
#   'Attribute': [],
#   'Disease': []},
#  {'id': 'Doctor',
#   'Sentence': '大便正常吗。',
#   'Symptom': [],
# ...

# %%
with open('new_test.pk','rb') as f:
    test_data = pickle.load(f)

# %%
print(type(test_data), len(test_data))
# Out:
# <class 'list'> 5649

# %%
test_data[:10]
# Out:
# [{'history': ['经常烧心，有返流情况（男，25岁）',
#    '经常吃奥美拉唑，吃完当时好，停药一段时间就反复发作。',
#    '你好，这种情况多久了？有没有查过胃镜。',
#    '建议做个胃镜看一下有无反流性食管炎及明确严重程度。',
#    '没有查过。',
#    '今年都是这样。',
#    '吃了多久药了啊。服药是否规律？',
#    '时间比较久了，要尽快查一下胃镜了。',
#    '也不是很规律。一般就是烧心的时候吃。',
#    '最多的时候连续吃了一周。'],
#   'response': ''},
#  {'history': ['请问体检幽门螺旋杆菌感染，阳性dpm:1897是什么意思？严重吗？（男，55岁）',
#    '你好，那是幽门螺杆菌检测的数量。',
#    '是啊。',
#    '1897很高了。你现在有啥症状吗？',
#    '没有。',
#    '有做胃镜检查吗？',
#    '没有啊。',
#    '一般我们都建议正规抗感染治疗的。',
#    '需要做吗。'],
#   'response': ''},
#  {'history': ['孕晚期，晚上上吐下泻，还肚子痛，可以喝益辅乐吗（女，29岁）',
#    '你好，这样有多长时间了？',
#    '你好。',
#    '嗯嗯。',
#    '是今晚五点多开始得。',
#    '中午吃的什么呢？',
#    '五点肚子痛，偶尔吐一点不多，我以为是孕晚期激素引起的。',
#    '七点开始，肚子痛的厉害了，就上吐，晚上八点泡了脚，就下泻了。',
#    '中午吃的烂肉豆腐，凉拌折耳根，蛋炒饭。',
#    '喝了点汤。',
#    '可以吃点益辅乐看看，',
#    '四点喝了鲫鱼汤一碗。',
#    '但如果症状一直不缓解，建议还是去医院看看。',
#    '我感觉我是受了风寒，五点我出门，外面天气变冷，还吹风，我穿的少，我现在吐了，身体还打寒冷，是不是有关系。',
#    '也有一定关系的。发烧吗？',
#    '不发烧。',
#    '嗯嗯。',
#    '可以喝红糖姜水吗，刚刚我妈妈给我煲的红糖姜水。',
#    '这种症状，对胎儿有没有影响，我现在肚子还痛。',
# ...
